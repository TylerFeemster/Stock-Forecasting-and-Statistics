# %%
import pandas as pd

df = pd.read_csv('./data/vwap.csv')
df_vol = pd.read_csv('./data/volume.csv')
df.index = list(df['Unnamed: 0'])
df_vol.index = list(df_vol['Unnamed: 0'])
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df_vol.drop(['Unnamed: 0'], axis=1, inplace=True)
display(df.describe())
df_vol.describe()
# Out:
#              AABA          AAL         AAPL          AAP         ABBV  \
# count  577.000000  2261.000000  2261.000000  2261.000000  2261.000000
# mean    18.928969    26.007341   101.471572   128.823423    95.124167
# std      1.682840    12.885818    64.907708    43.369924    43.451656
# min     14.800000     8.806702    20.710000    35.793493    36.000000
# 25%     17.840000    14.293075    40.690000   100.540000    61.500000
# 50%     19.190000    21.389519    88.950000   137.650000    79.310000
# 75%     20.140000    36.900000   157.140000   151.450000   135.270000
# max     22.530000    56.850000   258.937766   224.630000   204.178125
#
#               ABMD         ABNB          ABT         ACGL          ACN  ...  \
# count  1756.000000  1017.000000  2261.000000  2261.000000  2261.000000  ...
# mean    241.830245   140.027014    81.058193    43.637474   216.788761  ...
# std      93.912387    26.163841    29.224951    22.309578    87.664033  ...
# min      70.771658    82.779998    30.970000    20.600000    81.400000  ...
# 25%     153.225065   118.583914    53.520000    28.300000   140.630000  ...
# 50%     261.447236   139.835183    87.120000    35.150000   202.680000  ...
# 75%     315.319205   157.620229   106.250000    45.730000   299.050000  ...
# max     450.196189   215.769029   133.410000   108.850000   399.780000  ...
#
#                 XL          XOM         XRAY          XRX          XYL  \
# count  1729.000000  2261.000000  2261.000000  2261.000000  2261.000000
# mean     17.386338    68.555751    44.991940    30.072399    82.232749
# std      19.513909    24.598835    11.239881    35.675457    28.155469
# min       0.000000    24.840000    17.445559     8.147984    28.970000
# 25%       0.000000    54.340000    35.430000    14.380000    62.230000
# 50%       5.900126    59.100000    46.710000    18.650000    76.750000
# 75%      35.350000    91.150000    54.590000    21.990000   104.030000
# max      57.370000   124.600000    65.590000   149.290000   144.330000
#
#                YUM          ZBH         ZBRA         ZION          ZTS
# count  2261.000000  2261.000000  2261.000000  2261.000000  2261.000000
# mean     96.803983   120.504612   249.138325    39.004571   125.686942
# std      25.239708    16.233643   138.808387    10.392221    53.063521
# min      51.480000    76.120000    46.784023    15.680000    36.650000
# 25%      74.060000   109.350000   139.652080    32.610000    78.620000
# 50%      96.720000   117.880000   245.418744    39.380000   136.030000
# 75%     120.340000   128.410000   317.858225    45.920000   170.390000
# max     140.480000   173.760000   611.625112    66.680000   240.160000
#
# [8 rows x 679 columns]
#                AABA           AAL          AAPL           AAP          ABBV  \
# count  5.770000e+02  2.261000e+03  2.261000e+03  2.261000e+03  2.261000e+03
# mean   9.545343e+06  2.649442e+07  1.147709e+08  1.369164e+06  7.694587e+06
# std    7.314895e+06  2.879788e+07  6.359388e+07  1.165879e+06  4.557504e+06
# min    7.310500e+04  2.149570e+05  8.322060e+06  7.107000e+03  8.026180e+05
# 25%    5.069151e+06  7.276955e+06  7.395431e+07  8.026560e+05  5.146087e+06
# 50%    7.739328e+06  2.017429e+07  1.012391e+08  1.107822e+06  6.605217e+06
# 75%    1.165683e+07  3.503146e+07  1.388631e+08  1.586880e+06  8.942209e+06
# max    6.245403e+07  4.310589e+08  5.496353e+08  2.183231e+07  9.320786e+07
#
#                ABMD          ABNB           ABT          ACGL           ACN  \
# count  1.756000e+03  1.017000e+03  2.261000e+03  2.261000e+03  2.261000e+03
# mean   5.656563e+05  6.324233e+06  6.792045e+06  1.909148e+06  2.497359e+06
# std    9.484857e+05  5.268861e+06  3.681507e+06  2.971260e+06  1.152446e+06
# min    3.048600e+04  1.677060e+06  1.068073e+06  2.103540e+05  3.367500e+04
# 25%    2.861932e+05  3.905042e+06  4.659987e+06  1.189784e+06  1.816968e+06
# 50%    4.153795e+05  5.015162e+06  5.885879e+06  1.585218e+06  2.254026e+06
# 75%    6.314558e+05  6.980255e+06  7.793745e+06  2.149001e+06  2.815409e+06
# max    3.027713e+07  7.762090e+07  5.555083e+07  1.309742e+08  1.489915e+07
#
#        ...            XL           XOM          XRAY           XRX  \
# count  ...  1.729000e+03  2.261000e+03  2.261000e+03  2.261000e+03
# mean   ...  2.329199e+06  1.948490e+07  2.233327e+06  2.445005e+06
# std    ...  4.984539e+06  1.080066e+07  1.862938e+06  2.231910e+06
# min    ...  0.000000e+00  1.451244e+06  1.328480e+05  1.260160e+05
# 25%    ...  0.000000e+00  1.218350e+07  1.339917e+06  1.409189e+06
# 50%    ...  1.530489e+06  1.636549e+07  1.843773e+06  2.066547e+06
# 75%    ...  2.670916e+06  2.318564e+07  2.639436e+06  3.046878e+06
# max    ...  1.016847e+08  1.230629e+08  4.768549e+07  5.662682e+07
#
#                 XYL           YUM           ZBH          ZBRA          ZION  \
# count  2.261000e+03  2.261000e+03  2.261000e+03  2.261000e+03  2.261000e+03
# mean   1.283738e+06  2.258401e+06  1.495410e+06  4.646642e+05  2.574850e+06
# std    8.115061e+05  1.362691e+06  7.954333e+05  4.645585e+05  1.973378e+06
# min    9.363600e+04  1.720910e+05  1.560800e+05  3.029600e+04  8.617600e+04
# 25%    8.682800e+05  1.484502e+06  1.018687e+06  2.856030e+05  1.512041e+06
# 50%    1.128599e+06  1.915051e+06  1.308151e+06  3.836860e+05  2.123852e+06
# 75%    1.485606e+06  2.563901e+06  1.720021e+06  5.368410e+05  2.994677e+06
# max    2.024170e+07  2.290677e+07  1.057012e+07  1.675951e+07  3.741964e+07
#
#                 ZTS
# count  2.261000e+03
# mean   2.604717e+06
# std    1.325478e+06
# min    2.177520e+05
# 25%    1.749800e+06
# 50%    2.282813e+06
# 75%    3.099173e+06
# max    1.436580e+07
#
# [8 rows x 679 columns]

# %%
import numpy as np

df_log = df.copy()
df_log.iloc[:,:] = df.iloc[:,:].apply(lambda x: np.log1p(x))
df_log.describe()
# Out:
#              AABA          AAL         AAPL          AAP         ABBV  \
# count  577.000000  2261.000000  2261.000000  2261.000000  2261.000000
# mean     2.988495     3.180545     4.384968     4.796128     4.462905
# std      0.086624     0.483394     0.737354     0.401221     0.456327
# min      2.760010     2.283066     3.077773     3.605321     3.610918
# 25%      2.935982     2.727400     3.730261     4.620453     4.135167
# 50%      3.005187     3.108593     4.499254     4.931953     4.385894
# 75%      3.051167     3.634951     5.063481     5.026837     4.914638
# max      3.158276     4.057853     5.560442     5.418896     5.323879
#
#               ABMD         ABNB          ABT         ACGL          ACN  ...  \
# count  1756.000000  1017.000000  2261.000000  2261.000000  2261.000000  ...
# mean      5.402917     4.931502     4.329508     3.696886     5.294318  ...
# std       0.445050     0.188194     0.416707     0.429967     0.433826  ...
# min       4.273490     4.428194     3.464798     3.072693     4.411585  ...
# 25%       5.038413     4.784018     3.998568     3.377588     4.953218  ...
# 50%       5.570050     4.947590     4.478700     3.587677     5.316550  ...
# 75%       5.756752     5.066513     4.675163     3.844386     5.703949  ...
# max       6.111902     5.378832     4.900895     4.699116     5.993413  ...
#
#                 XL          XOM         XRAY          XRX          XYL  \
# count  1729.000000  2261.000000  2261.000000  2261.000000  2261.000000
# mean      1.895338     4.181377     3.794771     3.112596     4.359959
# std       1.633315     0.348850     0.268687     0.664578     0.360695
# min       0.000000     3.251924     2.914824     2.213534     3.400197
# 25%       0.000000     4.013496     3.595393     2.733068     4.146779
# 50%       1.931540     4.096010     3.865141     2.978077     4.353499
# 75%       3.593194     4.523418     4.018003     3.135059     4.654246
# max       4.066802     4.833102     4.198554     5.012567     4.979007
#
#                YUM          ZBH         ZBRA         ZION          ZTS
# count  2261.000000  2261.000000  2261.000000  2261.000000  2261.000000
# mean      4.547797     4.791393     5.345116     3.652017     4.731042
# std       0.269383     0.129762     0.631198     0.280367     0.500782
# min       3.960432     4.345363     3.866691     2.814210     3.628333
# 25%       4.318288     4.703657     4.946289     3.514824     4.377265
# 50%       4.582106     4.778115     5.507032     3.698335     4.920200
# 75%       4.798597     4.862986     5.764747     3.848444     5.143942
# max       4.952158     5.163414     6.417753     4.214791     5.485461
#
# [8 rows x 679 columns]

# %%
df_diff = df_log - df_log.shift()
df_diff.describe()
# Out:
#              AABA          AAL         AAPL          AAP         ABBV  \
# count  576.000000  2260.000000  2260.000000  2260.000000  2260.000000
# mean     0.000438    -0.000346     0.001045    -0.000491     0.000665
# std      0.014610     0.028151     0.015212     0.022607     0.015011
# min     -0.052411    -0.265160    -0.087484    -0.395992    -0.159689
# 25%     -0.006730    -0.013489    -0.006186    -0.009568    -0.005905
# 50%      0.000940    -0.000515     0.001286    -0.000156     0.001001
# 75%      0.008555     0.012982     0.008716     0.010058     0.008175
# max      0.055525     0.247390     0.086585     0.178196     0.112023
#
#               ABMD         ABNB          ABT         ACGL          ACN  ...  \
# count  1755.000000  1016.000000  2260.000000  2260.000000  2260.000000  ...
# mean      0.000842    -0.000096     0.000504     0.000627     0.000617  ...
# std       0.026046     0.027979     0.012866     0.014804     0.014131  ...
# min      -0.306084    -0.146404    -0.092727    -0.126506    -0.088086  ...
# 25%      -0.009809    -0.014113    -0.005872    -0.005711    -0.005160  ...
# 50%       0.001360    -0.000679     0.000768     0.001167     0.001303  ...
# 75%       0.012967     0.015887     0.007423     0.007677     0.007208  ...
# max       0.410950     0.126882     0.080450     0.115112     0.080369  ...
#
#                 XL          XOM         XRAY          XRX          XYL  \
# count  1728.000000  2260.000000  2260.000000  2260.000000  2260.000000
# mean     -0.001677     0.000316    -0.000443    -0.001142     0.000567
# std       0.123348     0.015595     0.018284     0.044390     0.015094
# min      -4.066802    -0.106498    -0.264124    -1.826940    -0.109662
# 25%      -0.003288    -0.006961    -0.008000    -0.009814    -0.006389
# 50%       0.000000     0.000389     0.000183     0.000643     0.000930
# 75%       0.002228     0.008022     0.008180     0.010400     0.008118
# max       2.952770     0.109382     0.144504     0.115595     0.075990
#
#                YUM          ZBH         ZBRA         ZION          ZTS
# count  2260.000000  2260.000000  2260.000000  2260.000000  2260.000000
# mean      0.000354     0.000052     0.000784     0.000414     0.000576
# std       0.014501     0.016014     0.021544     0.022574     0.014279
# min      -0.335891    -0.144572    -0.191136    -0.266458    -0.142142
# 25%      -0.005270    -0.006923    -0.009683    -0.010148    -0.006454
# 50%       0.000691     0.000410     0.001267     0.000864     0.001178
# 75%       0.006510     0.007565     0.010900     0.011201     0.007711
# max       0.175854     0.119708     0.134300     0.195821     0.083857
#
# [8 rows x 679 columns]

# %%
corr = df_diff.corr()
display(corr.mean(axis=1).sort_values())
# Out:
# POM    -0.077416
# MON     0.009737
# STI     0.013697
# EMC     0.016400
# LLL     0.019662
#           ...
# AMP     0.424125
# WYND    0.442763
# CAM     0.447530
# PCL     0.538002
# DOW          NaN
# Length: 679, dtype: float64

# %%
for idx, row in corr.iterrows():
    for col in corr.columns:
        if idx != col and row[col] > 0.95:
            print(f"{col:6}{idx:6}{row[col]:.5f}")
# Out:
# SLB   CAM   0.98929
# DISCK DISCA 0.97283
# WBD   DISCA 0.97227
# DISCA DISCK 0.97283
# WBD   DISCK 0.98037
# KSU   HCP   1.00000
# FOX   FOXA  0.98478
# FOXA  FOX   0.98478
# GOOG  GOOGL 0.99494
# GOOGL GOOG  0.99494
# HCP   KSU   1.00000
# VTRS  MYL   1.00000
# PLTR  NBL   1.00000
# NWS   NWSA  0.97918
# NWSA  NWS   0.97918
# WY    PCL   0.99524
# NBL   PLTR  1.00000
# CAM   SLB   0.98929
# MYL   VTRS  1.00000
# DISCA WBD   0.97227
# DISCK WBD   0.98037
# PCL   WY    0.99524

# %%
df_diff.drop(['GOOGL', 'FOXA', 'NWSA'], axis=1, inplace=True)
corr = df_diff.corr()

# %% [markdown]
# ## Intra-Sector

# %%
df_sp = pd.read_csv('./data/s&p500.csv')
sectors = list(df_sp['GICS Sector'].value_counts().index)

# %%
print(df_sp.index)

by_industry = {}
for sector in sectors:
    stocks = list(df_sp.loc[df_sp['GICS Sector'] == sector]['Symbol'])
    stks = [stk for stk in stocks if stk in corr.columns]
    by_industry[sector] = stks
    print(f"{sector:25}", stks)
# Out:
# RangeIndex(start=0, stop=502, step=1)
# Industrials               ['MMM', 'AOS', 'ALLE', 'AMTM', 'AME', 'ADP', 'AXON', 'BA', 'BR', 'BLDR', 'CHRW', 'CARR', 'CAT', 'CTAS', 'CPRT', 'CSX', 'CMI', 'DAY', 'DE', 'DAL', 'DOV', 'ETN', 'EMR', 'EFX', 'EXPD', 'FAST', 'FDX', 'FTV', 'GE', 'GEV', 'GNRC', 'GD', 'HON', 'HWM', 'HUBB', 'HII', 'IEX', 'ITW', 'IR', 'JBHT', 'J', 'JCI', 'LHX', 'LDOS', 'LMT', 'MAS', 'NDSN', 'NSC', 'NOC', 'ODFL', 'OTIS', 'PCAR', 'PH', 'PAYX', 'PAYC', 'PNR', 'PWR', 'RTX', 'RSG', 'ROK', 'ROL', 'SNA', 'LUV', 'SWK', 'TXT', 'TT', 'TDG', 'UBER', 'UNP', 'UAL', 'UPS', 'URI', 'VLTO', 'VRSK', 'GWW', 'WAB', 'WM', 'XYL']
# Financials                ['AFL', 'ALL', 'AXP', 'AIG', 'AMP', 'AON', 'ACGL', 'AJG', 'AIZ', 'BAC', 'BRK.B', 'BLK', 'BX', 'BK', 'BRO', 'COF', 'CBOE', 'SCHW', 'CB', 'CINF', 'C', 'CFG', 'CME', 'CPAY', 'DFS', 'ERIE', 'EG', 'FDS', 'FIS', 'FITB', 'FI', 'BEN', 'GPN', 'GL', 'GS', 'HIG', 'HBAN', 'ICE', 'IVZ', 'JKHY', 'JPM', 'KEY', 'KKR', 'L', 'MTB', 'MKTX', 'MMC', 'MA', 'MET', 'MCO', 'MS', 'MSCI', 'NDAQ', 'NTRS', 'PYPL', 'PNC', 'PFG', 'PGR', 'PRU', 'RJF', 'RF', 'SPGI', 'STT', 'SYF', 'TROW', 'TRV', 'TFC', 'USB', 'V', 'WRB', 'WFC', 'WTW']
# Information Technology    ['ACN', 'ADBE', 'AMD', 'AKAM', 'APH', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ANET', 'ADSK', 'AVGO', 'CDNS', 'CDW', 'CSCO', 'CTSH', 'GLW', 'CRWD', 'DELL', 'ENPH', 'EPAM', 'FFIV', 'FICO', 'FSLR', 'FTNT', 'IT', 'GEN', 'GDDY', 'HPE', 'HPQ', 'IBM', 'INTC', 'INTU', 'JBL', 'JNPR', 'KEYS', 'KLAC', 'LRCX', 'MCHP', 'MU', 'MSFT', 'MPWR', 'MSI', 'NTAP', 'NVDA', 'NXPI', 'ON', 'ORCL', 'PLTR', 'PANW', 'PTC', 'QRVO', 'QCOM', 'ROP', 'CRM', 'STX', 'NOW', 'SWKS', 'SMCI', 'SNPS', 'TEL', 'TDY', 'TER', 'TXN', 'TRMB', 'TYL', 'VRSN', 'WDC', 'ZBRA']
# Health Care               ['ABT', 'ABBV', 'A', 'ALGN', 'AMGN', 'BAX', 'BDX', 'TECH', 'BIIB', 'BSX', 'BMY', 'CAH', 'COR', 'CNC', 'CRL', 'CI', 'COO', 'CVS', 'DHR', 'DVA', 'DXCM', 'EW', 'ELV', 'GEHC', 'GILD', 'HCA', 'HSIC', 'HOLX', 'HUM', 'IDXX', 'INCY', 'PODD', 'ISRG', 'IQV', 'JNJ', 'LH', 'LLY', 'MCK', 'MDT', 'MRK', 'MTD', 'MRNA', 'MOH', 'PFE', 'DGX', 'REGN', 'RMD', 'RVTY', 'SOLV', 'STE', 'SYK', 'TFX', 'TMO', 'UNH', 'UHS', 'VRTX', 'VTRS', 'WAT', 'WST', 'ZBH', 'ZTS']
# Consumer Discretionary    ['ABNB', 'AMZN', 'APTV', 'AZO', 'BBY', 'BKNG', 'BWA', 'CZR', 'KMX', 'CCL', 'CMG', 'DRI', 'DECK', 'DPZ', 'DHI', 'EBAY', 'EXPE', 'F', 'GRMN', 'GM', 'GPC', 'HAS', 'HLT', 'HD', 'LVS', 'LEN', 'LKQ', 'LOW', 'LULU', 'MAR', 'MCD', 'MGM', 'MHK', 'NKE', 'NCLH', 'NVR', 'ORLY', 'POOL', 'PHM', 'RL', 'ROST', 'RCL', 'SBUX', 'TPR', 'TSLA', 'TJX', 'TSCO', 'ULTA', 'WYNN', 'YUM']
# Consumer Staples          ['MO', 'ADM', 'BF.B', 'BG', 'CPB', 'CHD', 'CLX', 'KO', 'CL', 'CAG', 'STZ', 'COST', 'DG', 'DLTR', 'EL', 'GIS', 'HSY', 'HRL', 'K', 'KVUE', 'KDP', 'KMB', 'KHC', 'KR', 'LW', 'MKC', 'TAP', 'MDLZ', 'MNST', 'PEP', 'PM', 'PG', 'SJM', 'SYY', 'TGT', 'TSN', 'WBA', 'WMT']
# Utilities                 ['AES', 'LNT', 'AEE', 'AEP', 'AWK', 'ATO', 'CNP', 'CMS', 'ED', 'CEG', 'D', 'DTE', 'DUK', 'EIX', 'ETR', 'EVRG', 'ES', 'EXC', 'FE', 'NEE', 'NI', 'NRG', 'PCG', 'PNW', 'PPL', 'PEG', 'SRE', 'SO', 'VST', 'WEC', 'XEL']
# Real Estate               ['ARE', 'AMT', 'AVB', 'BXP', 'CPT', 'CBRE', 'CSGP', 'CCI', 'DLR', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'DOC', 'HST', 'INVH', 'IRM', 'KIM', 'MAA', 'PLD', 'PSA', 'O', 'REG', 'SBAC', 'SPG', 'UDR', 'VTR', 'VICI', 'WELL', 'WY']
# Materials                 ['APD', 'ALB', 'AMCR', 'AVY', 'BALL', 'CE', 'CF', 'CTVA', 'DOW', 'DD', 'EMN', 'ECL', 'FMC', 'FCX', 'IFF', 'IP', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PKG', 'PPG', 'SHW', 'SW', 'STLD', 'VMC']
# Communication Services    ['GOOG', 'T', 'CHTR', 'CMCSA', 'EA', 'FOX', 'IPG', 'LYV', 'MTCH', 'META', 'NFLX', 'NWS', 'OMC', 'PARA', 'TMUS', 'TTWO', 'VZ', 'DIS', 'WBD']
# Energy                    ['APA', 'BKR', 'CVX', 'COP', 'CTRA', 'DVN', 'FANG', 'EOG', 'EQT', 'XOM', 'HAL', 'HES', 'KMI', 'MPC', 'OXY', 'OKE', 'PSX', 'SLB', 'TRGP', 'TPL', 'VLO', 'WMB']

# %%
series = pd.Series()
for sector in sectors:
    stks = by_industry[sector]
    series[sector] = (corr.loc[stks, stks].sum(0).sum(0) - len(stks)) / (len(stks) * (len(stks) - 1))

series.sort_values(inplace=True)

# %% [markdown]
# ## Inter-Sector

# %%
df_by_sector = pd.DataFrame()
for sector in sectors:
    stks = by_industry[sector]
    df_by_sector[sector] = (df[stks] * df_vol[stks]).sum(axis=1) / df_vol[stks].sum(axis=1)

df_sect_log = df_by_sector.iloc[:,:].apply(lambda x: np.log1p(x))
df_sector_diffs = df_sect_log - df_sect_log.shift()

display(df_sector_diffs.describe())

sector_corr = df_sector_diffs.corr()

sector_corr['sort_col'] = sector_corr.sum(axis=0)

sector_corr.sort_values(by='sort_col', inplace=True, ascending=False)

sector_corr.drop('sort_col', axis=1, inplace=True)

# permute columns to match sorted ordering
sector_corr = sector_corr[sector_corr.index]
# Out:
#        Industrials   Financials  Information Technology  Health Care  \
# count  2260.000000  2260.000000             2260.000000  2260.000000
# mean      0.000409     0.000534                0.000875     0.000298
# std       0.071936     0.055963                0.111315     0.064782
# min      -0.716441    -0.357055               -0.687929    -0.464929
# 25%      -0.038280    -0.032166               -0.054100    -0.032394
# 50%       0.000283     0.002364                0.006280     0.001190
# 75%       0.039863     0.035105                0.061461     0.035508
# max       0.677992     0.298732                0.574781     0.455239
#
#        Consumer Discretionary  Consumer Staples    Utilities  Real Estate  \
# count             2260.000000       2260.000000  2260.000000  2260.000000
# mean                 0.000865          0.000230     0.000377     0.000218
# std                  0.098886          0.056986     0.065933     0.075655
# min                 -0.515150         -0.448837    -0.539582    -0.489594
# 25%                 -0.052209         -0.028218    -0.029290    -0.042744
# 50%                  0.001384          0.000839     0.001090     0.000520
# 75%                  0.055243          0.030626     0.031673     0.042681
# max                  0.739557          0.365526     0.603335     0.599933
#
#          Materials  Communication Services       Energy
# count  2260.000000             2260.000000  2260.000000
# mean      0.000371                0.000358     0.000294
# std       0.096406                0.119635     0.053273
# min      -0.932151               -0.740410    -0.374571
# 25%      -0.050765               -0.065859    -0.029865
# 50%       0.000273                0.001199     0.000194
# 75%       0.052216                0.064942     0.031345
# max       0.837700                0.754074     0.366181

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(series, orient='h')
plt.title('Correlation of Stocks within Industries')
plt.show()

sns.heatmap(sector_corr, vmax=0.2, vmin=-0.1, center=0, cmap='coolwarm')
plt.title('Correlation of Stocks between Industries')
plt.show()

# %% [markdown]
# ### Statistical Significance

# %%
from scipy.stats import t
import matplotlib.pyplot as plt

def p_value(n, dataframe: pd.DataFrame) -> pd.DataFrame:
    p_val = pd.DataFrame(index=dataframe.index, columns=dataframe.columns)
    for sector in sectors:
        t_stat = dataframe[sector] * np.sqrt((n - 2) / (1 - dataframe[sector]**2))
        p_val[sector] = 2 * t.sf(np.abs(t_stat), df=n-2)
        p_val.index = dataframe.index
    return p_val

pval = p_value(len(df_sector_diffs), sector_corr)
pval = pval[sector_corr.columns]
# shuffle indices to match sector_corr indices
pval = pval.loc[sector_corr.index]

# correlation heatmap
sns.heatmap(sector_corr, vmax=0.2, vmin=-0.1, center=0, cmap='coolwarm')
plt.title('Correlation of Stocks between Industries')
plt.show()

sns.heatmap(pval, vmax=0.1, vmin=0, center=0.05, cmap=plt.cm.coolwarm.reversed())
plt.title('P-Value of Correlation between Industries')
plt.show()

# %% [markdown]
# ### Strength of Correlation

# %%
def correlation_strength(corr: pd.DataFrame, pval: pd.DataFrame) -> pd.DataFrame:
    epsilon = 1e-20
    strength = pd.DataFrame(index=corr.index, columns=corr.columns)
    for sector in sectors:
        strength[sector] = corr[sector] * pval[sector].apply(lambda x: max(-np.log10(x + epsilon), 1))
        print(strength[sector])
    return strength

strength = correlation_strength(sector_corr, pval)
sns.heatmap(strength, vmax=0.5, vmin=-0.5, center=0, cmap='coolwarm')
plt.title('Strength of Correlation between Stocks between Industries')
plt.show()
# Out:
# Financials                 0.252559
# Materials                  0.015039
# Real Estate                0.091947
# Consumer Discretionary    -0.132785
# Consumer Staples          -0.031893
# Health Care                0.034203
# Energy                     0.097732
# Utilities                  0.017204
# Information Technology     0.007997
# Industrials               20.000000
# Communication Services    -0.048614
# Name: Industrials, dtype: float64
# Financials                20.000000
# Materials                  0.867139
# Real Estate                0.649489
# Consumer Discretionary     0.488983
# Consumer Staples           0.118550
# Health Care                0.111278
# Energy                     0.487582
# Utilities                 -0.004711
# Information Technology     0.033252
# Industrials                0.252559
# Communication Services     0.191124
# Name: Financials, dtype: float64
# Financials                 0.033252
# Materials                  0.114263
# Real Estate                0.002555
# Consumer Discretionary     0.119670
# Consumer Staples           0.026525
# Health Care                0.054462
# Energy                     0.117635
# Utilities                  0.030795
# Information Technology    20.000000
# Industrials                0.007997
# Communication Services    -0.061076
# Name: Information Technology, dtype: float64
# Financials                 0.111278
# Materials                  0.291014
# Real Estate                0.102696
# Consumer Discretionary     0.030446
# Consumer Staples           0.033117
# Health Care               20.000000
# Energy                    -0.072408
# Utilities                 -0.004143
# Information Technology     0.054462
# Industrials                0.034203
# Communication Services     0.050760
# Name: Health Care, dtype: float64
# Financials                 0.488983
# Materials                  0.025612
# Real Estate                0.054700
# Consumer Discretionary    20.000000
# Consumer Staples           0.032956
# Health Care                0.030446
# Energy                     0.075277
# Utilities                  0.501499
# Information Technology     0.119670
# Industrials               -0.132785
# Communication Services     0.029524
# Name: Consumer Discretionary, dtype: float64
# Financials                 0.118550
# Materials                  0.047715
# Real Estate                0.026223
# Consumer Discretionary     0.032956
# Consumer Staples          20.000000
# Health Care                0.033117
# Energy                     0.060479
# Utilities                  0.042847
# Information Technology     0.026525
# Industrials               -0.031893
# Communication Services     0.152301
# Name: Consumer Staples, dtype: float64
# Financials                -0.004711
# Materials                  0.069215
# Real Estate                0.014654
# Consumer Discretionary     0.501499
# Consumer Staples           0.042847
# Health Care               -0.004143
# Energy                     0.022134
# Utilities                 20.000000
# Information Technology     0.030795
# Industrials                0.017204
# Communication Services     0.064222
# Name: Utilities, dtype: float64
# Financials                 0.649489
# Materials                  0.831293
# Real Estate               20.000000
# Consumer Discretionary     0.054700
# Consumer Staples           0.026223
# Health Care                0.102696
# Energy                     0.074631
# Utilities                  0.014654
# Information Technology     0.002555
# Industrials                0.091947
# Communication Services    -0.003884
# Name: Real Estate, dtype: float64
# Financials                 0.867139
# Materials                 20.000000
# Real Estate                0.831293
# Consumer Discretionary     0.025612
# Consumer Staples           0.047715
# Health Care                0.291014
# Energy                     0.058095
# Utilities                  0.069215
# Information Technology     0.114263
# Industrials                0.015039
# Communication Services    -0.002980
# Name: Materials, dtype: float64
# Financials                 0.191124
# Materials                 -0.002980
# Real Estate               -0.003884
# Consumer Discretionary     0.029524
# Consumer Staples           0.152301
# Health Care                0.050760
# Energy                    -0.060041
# Utilities                  0.064222
# Information Technology    -0.061076
# Industrials               -0.048614
# Communication Services    20.000000
# Name: Communication Services, dtype: float64
# Financials                 0.487582
# Materials                  0.058095
# Real Estate                0.074631
# Consumer Discretionary     0.075277
# Consumer Staples           0.060479
# Health Care               -0.072408
# Energy                    20.000000
# Utilities                  0.022134
# Information Technology     0.117635
# Industrials                0.097732
# Communication Services    -0.060041
# Name: Energy, dtype: float64

# %%
result = pd.concat([
    pd.Series(
        [df_sector_diffs[idx].corr(df_sector_diffs[col].shift()) for idx in df_sector_diffs.columns], 
        index=df_sector_diffs.columns) for col in df_sector_diffs.columns], axis=1)
result.columns = df_sector_diffs.columns

sns.heatmap(result, vmax=0.1, vmin=-0.1, center=0, cmap='coolwarm')
plt.title('Correlation of Stocks between Industries Shifted by 1 Day')
plt.show()

pval2 = p_value(len(df_sector_diffs) - 1, result)

pval2['sort_col'] = pval2.sum(axis=0)
pval2.sort_values(by='sort_col', inplace=True, ascending=False)
pval2.drop('sort_col', axis=1, inplace=True)
pval2 = pval2[pval2.index]

sns.heatmap(pval2, vmax=0.1, vmin=0, center=0.05,
            cmap=plt.cm.coolwarm.reversed())
plt.title('P-Values of Correlations of Stocks between Industries Shifted by 1 Day')
plt.show()

# %%
import cvxpy as cp
import numpy as np

# Problem data
Q = df_diff.cov().to_numpy()  
r = df_diff.mean(axis=0).to_numpy()        
betas = [.001, .0005, .0002, .0001]                     

for beta in betas:
    # Variables
    n = Q.shape[0]
    p = cp.Variable(n)
    print(n)
    print(r.shape)

    # Constraints
    constraints = [
        cp.sum(p) == 1,
        p @ r == beta,
        p >= 0
    ]

    # Objective
    objective = cp.Minimize(cp.quad_form(p, Q))

    # Solve
    problem = cp.Problem(objective, constraints)
    problem.solve()

    # Solution
    optimal_series = pd.Series(1000 * np.round(p.value, 3), index=df_diff.columns)
    optimal_series = optimal_series[optimal_series > 0]

    print("Optimal p:", optimal_series)
    print(f"{beta:6} Optimal objective value:", problem.value)
# Out:
# 676
# (676,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 24
#      17 constraints = [
#      18     cp.sum(p) == 1,
#      19     p @ r == beta,
#      20     p >= 0
#      21 ]
#      23 # Objective
# ---> 24 objective = cp.Minimize(cp.quad_form(p, Q))
#      26 # Solve
#      27 problem = cp.Problem(objective, constraints)
#
# File c:\Users\ttfee\OneDrive\Desktop\Stock Forecasting\.venv\Lib\site-packages\cvxpy\atoms\quad_form.py:250, in quad_form(x, P, assume_PSD)
#     248     if assume_PSD:
#     249         P = psd_wrap(P)
# --> 250     return QuadForm(x, P)
#     251 else:
#     252     raise Exception(
#     253         "At least one argument to quad_form must be non-variable."
#     254     )
#
# File c:\Users\ttfee\OneDrive\Desktop\Stock Forecasting\.venv\Lib\site-packages\cvxpy\atoms\quad_form.py:40, in QuadForm.__init__(self, x, P)
#      38 def __init__(self, x, P) -> None:
#      39     """Atom representing :math:`x^T P x`."""
# ---> 40     super(QuadForm, self).__init__(x, P)
#
# File c:\Users\ttfee\OneDrive\Desktop\Stock Forecasting\.venv\Lib\site-packages\cvxpy\atoms\atom.py:50, in Atom.__init__(self, *args)
#      48 # Convert raw values to Constants.
#      49 self.args = [Atom.cast_to_const(arg) for arg in args]
# ---> 50 self.validate_arguments()
#      51 self._shape = self.shape_from_args()
#      52 if not s.ALLOW_ND_EXPR and len(self._shape) > 2:
#
# File c:\Users\ttfee\OneDrive\Desktop\Stock Forecasting\.venv\Lib\site-packages\cvxpy\atoms\quad_form.py:56, in QuadForm.validate_arguments(self)
#      54     raise ValueError("Invalid dimensions for arguments.")
#      55 if not self.args[1].is_hermitian():
# ---> 56     raise ValueError("Quadratic form matrices must be symmetric/Hermitian.")
#
# ValueError: Quadratic form matrices must be symmetric/Hermitian.
