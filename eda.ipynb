# %%
import pandas as pd

df = pd.read_csv('./data/vwap.csv')
df_vol = pd.read_csv('./data/volume.csv')
df.index = list(df['Unnamed: 0'])
df_vol.index = list(df_vol['Unnamed: 0'])
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df_vol.drop(['Unnamed: 0'], axis=1, inplace=True)
display(df.describe())
df_vol.describe()
# Out:
#               MMM         AOS         ABT        ABBV         ACN        ADBE  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean   123.183701   80.115465  111.472651  183.269892  337.320465  520.988686
# std     13.120600    5.202775    5.261621   11.813186   25.306290   35.602649
# min     98.488375   68.435773  101.095634  160.454323  282.668916  440.871856
# 25%    104.582700   76.025984  105.933319  171.886153  319.829046  498.237149
# 50%    128.789076   80.957566  113.043601  185.796711  341.123733  523.525510
# 75%    132.851735   83.058466  115.946788  193.742829  359.533588  552.447393
# max    139.348901   91.238165  119.300028  204.178125  376.113026  582.408926
#
#               AMD         AES         AFL           A  ...          WY  \
# count  142.000000  142.000000  142.000000  142.000000  ...  142.000000
# mean   150.626391   16.879743  103.196395  136.444729  ...   30.812812
# std     13.821957    2.235306    8.837269    5.139834  ...    1.653489
# min    119.761748   12.399499   86.933963  125.094283  ...   27.192531
# 25%    139.898389   15.521837   94.457924  132.839671  ...   29.836232
# 50%    151.863898   17.332401  105.738255  137.011423  ...   30.838076
# 75%    160.478516   18.512479  110.218137  139.937053  ...   31.834295
# max    184.173390   20.923797  115.117429  148.668367  ...   33.824571
#
#               WMB         WTW        WYNN         XEL         XYL         YUM  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean    47.764434  287.841615   87.875385   61.841000  131.730527  134.442240
# std      5.658255   20.368742    8.544803    5.729203    5.977987    3.354269
# min     40.793281  253.912597   73.437377   52.213535  116.918157  126.047011
# 25%     42.891886  269.769798   80.274017   56.376198  127.493817  132.529178
# 50%     45.205604  290.432084   88.379154   62.977513  133.093309  134.384219
# 75%     52.485120  302.165884   94.276432   66.047862  136.592201  137.166845
# max     59.752646  332.090409  106.326221   72.932332  141.382681  141.339423
#
#              ZBRA         ZBH         ZTS
# count  142.000000  142.000000  142.000000
# mean   352.928714  108.508560  181.105611
# std     34.332423    3.060418    7.584028
# min    296.825341  101.977383  163.876326
# 25%    324.124863  106.549607  175.817440
# 50%    351.255320  108.110467  180.565987
# 75%    381.512851  110.585801  187.326356
# max    411.259686  116.052997  196.403919
#
# [8 rows x 501 columns]
#                 MMM           AOS           ABT          ABBV           ACN  \
# count  1.420000e+02  1.420000e+02  1.420000e+02  1.420000e+02  1.420000e+02
# mean   3.840678e+06  9.934295e+05  5.655506e+06  5.636374e+06  2.799349e+06
# std    2.997691e+06  4.233635e+05  2.416093e+06  3.073928e+06  1.667992e+06
# min    1.230776e+06  3.813260e+05  2.017846e+06  2.395181e+06  1.195275e+06
# 25%    2.685503e+06  7.093968e+05  4.074481e+06  4.069204e+06  1.987641e+06
# 50%    3.130210e+06  8.793175e+05  5.027552e+06  4.737745e+06  2.340296e+06
# 75%    3.936785e+06  1.149555e+06  6.515422e+06  6.130017e+06  3.149020e+06
# max    3.274892e+07  2.859727e+06  1.945269e+07  2.443395e+07  1.489915e+07
#
#                ADBE           AMD           AES           AFL             A  \
# count  1.420000e+02  1.420000e+02  1.420000e+02  1.420000e+02  1.420000e+02
# mean   3.268458e+06  4.329960e+07  1.012446e+07  2.209620e+06  1.851066e+06
# std    2.313705e+06  1.693607e+07  5.747386e+06  1.069202e+06  9.995064e+05
# min    1.219609e+06  1.608571e+07  3.243084e+06  1.040045e+06  6.346730e+05
# 25%    2.015818e+06  3.097331e+07  6.266116e+06  1.629414e+06  1.285678e+06
# 50%    2.720991e+06  4.054004e+07  8.383822e+06  1.928950e+06  1.670392e+06
# 75%    3.426990e+06  4.965229e+07  1.181826e+07  2.480534e+06  2.135084e+06
# max    1.734486e+07  1.143068e+08  3.089524e+07  8.463031e+06  9.800296e+06
#
#        ...            WY           WMB           WTW          WYNN  \
# count  ...  1.420000e+02  1.420000e+02  1.420000e+02  1.420000e+02
# mean   ...  3.769742e+06  6.151433e+06  5.619390e+05  2.522987e+06
# std    ...  1.366322e+06  2.184496e+06  2.642378e+05  1.649451e+06
# min    ...  1.639017e+06  2.685707e+06  1.944040e+05  1.026539e+06
# 25%    ...  2.902409e+06  4.603486e+06  3.745202e+05  1.621775e+06
# 50%    ...  3.396487e+06  5.747552e+06  4.985395e+05  2.025434e+06
# 75%    ...  4.224554e+06  7.360653e+06  6.935435e+05  2.682316e+06
# max    ...  1.143549e+07  1.684345e+07  2.033882e+06  1.125306e+07
#
#                 XEL           XYL           YUM          ZBRA           ZBH  \
# count  1.420000e+02  1.420000e+02  1.420000e+02  1.420000e+02  1.420000e+02
# mean   3.452614e+06  1.270904e+06  1.890374e+06  3.518074e+05  1.553502e+06
# std    1.714054e+06  5.633104e+05  7.038851e+05  1.755523e+05  6.719878e+05
# min    1.178345e+06  6.438780e+05  9.359340e+05  1.065830e+05  5.040580e+05
# 25%    2.410348e+06  8.975150e+05  1.419305e+06  2.407102e+05  1.166074e+06
# 50%    3.009674e+06  1.088770e+06  1.711366e+06  3.054800e+05  1.428166e+06
# 75%    4.068201e+06  1.551902e+06  2.178696e+06  4.041342e+05  1.805210e+06
# max    1.306078e+07  4.258867e+06  5.814643e+06  1.319682e+06  4.929017e+06
#
#                 ZTS
# count  1.420000e+02
# mean   2.180390e+06
# std    8.860485e+05
# min    9.594650e+05
# 25%    1.637310e+06
# 50%    1.960360e+06
# 75%    2.460874e+06
# max    6.220139e+06
#
# [8 rows x 501 columns]

# %%
import numpy as np

df_log = df.copy()
df_log.iloc[:,:] = df.iloc[:,:].apply(lambda x: np.log1p(x))
df_log.describe()
# Out:
#               MMM         AOS         ABT        ABBV         ACN        ADBE  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean     4.815795    4.393811    4.721605    5.214344    5.821119    6.255286
# std      0.111655    0.064637    0.047393    0.064504    0.076768    0.069330
# min      4.600041    4.240402    4.625910    5.084222    5.647808    6.091020
# 25%      4.659494    4.344143    4.672205    5.152633    5.770908    6.213081
# 50%      4.865910    4.406202    4.736581    5.230021    5.835172    6.262494
# 75%      4.896733    4.431513    4.761719    5.271680    5.887585    6.316167
# max      4.944131    4.524374    4.789989    5.323879    5.932545    6.368888
#
#               AMD         AES         AFL           A  ...          WY  \
# count  142.000000  142.000000  142.000000  142.000000  ...  142.000000
# mean     5.017271    2.875454    4.642570    4.922526  ...    3.458512
# std      0.091602    0.130549    0.087223    0.037470  ...    0.052449
# min      4.793820    2.595217    4.476586    4.837030  ...    3.339057
# 25%      4.948039    2.804405    4.558685    4.896643  ...    3.428690
# 50%      5.029547    2.908668    4.670371    4.927336  ...    3.460663
# 75%      5.084372    2.971054    4.711493    4.948313  ...    3.491474
# max      5.221293    3.087573    4.754602    5.008422  ...    3.550323
#
#               WMB         WTW        WYNN         XEL         XYL         YUM  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean     3.880545    5.663401    4.482630    4.136437    4.887295    4.908239
# std      0.113052    0.070719    0.096430    0.091927    0.045684    0.024890
# min      3.732736    5.540921    4.309958    3.974313    4.769991    4.844557
# 25%      3.781729    5.601212    4.397826    4.049604    4.855881    4.894320
# 50%      3.833101    5.674807    4.492887    4.158532    4.898536    4.908117
# 75%      3.979403    5.714277    4.556782    4.205401    4.924294    4.928462
# max      4.106811    5.808414    4.675873    4.303150    4.958518    4.958215
#
#              ZBRA         ZBH         ZTS
# count  142.000000  142.000000  142.000000
# mean     5.864408    4.695617    5.203728
# std      0.097268    0.027845    0.041561
# min      5.696507    4.634509    5.105196
# 25%      5.784208    4.677952    5.175118
# 50%      5.864354    4.692361    5.201619
# 75%      5.946762    4.714794    5.238175
# max      6.021653    4.762627    5.285252
#
# [8 rows x 501 columns]

# %%
df_diff = df_log - df_log.shift()
df_diff.describe()
# Out:
#               MMM         AOS         ABT        ABBV         ACN        ADBE  \
# count  141.000000  141.000000  141.000000  141.000000  141.000000  141.000000
# mean     0.001800   -0.001278    0.000708    0.000708    0.001685    0.000091
# std      0.017955    0.015460    0.010520    0.016450    0.014259    0.022907
# min     -0.045093   -0.080322   -0.035925   -0.133021   -0.038354   -0.133263
# 25%     -0.006329   -0.009582   -0.005448   -0.006235   -0.005525   -0.007503
# 50%     -0.000156   -0.001094   -0.000121    0.000547    0.001315    0.001324
# 75%      0.007161    0.006572    0.006193    0.007744    0.008453    0.009688
# max      0.168491    0.042325    0.044763    0.050706    0.065301    0.138312
#
#               AMD         AES         AFL           A  ...          WY  \
# count  141.000000  141.000000  141.000000  141.000000  ...  141.000000
# mean    -0.001960   -0.003177    0.000998    0.000140  ...   -0.000440
# std      0.024979    0.021313    0.011966    0.014031  ...    0.013369
# min     -0.089163   -0.093724   -0.044771   -0.038329  ...   -0.039932
# 25%     -0.015325   -0.013401   -0.004899   -0.009435  ...   -0.008790
# 50%     -0.000900   -0.001297    0.001390   -0.000115  ...   -0.001508
# 75%      0.013743    0.007819    0.007178    0.009237  ...    0.007554
# max      0.057779    0.058779    0.067780    0.049122  ...    0.049226
#
#               WMB         WTW        WYNN         XEL         XYL         YUM  \
# count  141.000000  141.000000  141.000000  141.000000  141.000000  141.000000
# mean     0.001897    0.001471   -0.000485    0.001400   -0.001173   -0.000289
# std      0.012305    0.010188    0.020564    0.010742    0.012876    0.009417
# min     -0.035060   -0.034689   -0.088551   -0.021871   -0.058165   -0.020539
# 25%     -0.004137   -0.003768   -0.011212   -0.004989   -0.007280   -0.006792
# 50%      0.002206    0.001689    0.000064    0.000821    0.000993   -0.001326
# 75%      0.009846    0.005855    0.008499    0.006454    0.005935    0.005253
# max      0.042284    0.036642    0.078406    0.058200    0.024622    0.034180
#
#              ZBRA         ZBH         ZTS
# count  141.000000  141.000000  141.000000
# mean     0.001710   -0.000456   -0.000354
# std      0.015125    0.013010    0.012557
# min     -0.060511   -0.085757   -0.033047
# 25%     -0.006922   -0.006648   -0.007831
# 50%      0.002718    0.000129    0.000151
# 75%      0.009260    0.006552    0.007447
# max      0.062771    0.043600    0.055395
#
# [8 rows x 501 columns]

# %%
corr = df_diff.corr()
display(corr.mean(axis=1).sort_values())
# Out:
# K      -0.063131
# CBOE   -0.061794
# CTAS   -0.020614
# TSCO   -0.020291
# DXCM   -0.017931
#           ...
# PNC     0.310033
# TXT     0.310210
# USB     0.310331
# EMN     0.311187
# FITB    0.314280
# Length: 501, dtype: float64

# %%
for idx, row in corr.iterrows():
    for col in corr.columns:
        if idx != col and row[col] > 0.95:
            print(f"{col:6}{idx:6}{row[col]:.5f}")
# Out:
# GOOG  GOOGL 0.99870
# GOOGL GOOG  0.99870
# DFS   COF   0.96471
# HES   CVX   0.95637
# COF   DFS   0.96471
# FOX   FOXA  0.98513
# FOXA  FOX   0.98513
# CVX   HES   0.95637
# NWS   NWSA  0.95994
# NWSA  NWS   0.95994

# %%
df_diff.drop(['GOOGL', 'FOXA', 'NWSA'], axis=1, inplace=True)
corr = df_diff.corr()

# %% [markdown]
# ## Intra-Sector

# %%
df_sp = pd.read_csv('./data/s&p500.csv')
sectors = list(df_sp['GICS Sector'].value_counts().index)

# %%
print(df_sp.index)

by_industry = {}
for sector in sectors:
    stocks = list(df_sp.loc[df_sp['GICS Sector'] == sector]['Symbol'])
    stks = [stk for stk in stocks if stk in corr.columns]
    by_industry[sector] = stks
    print(f"{sector:25}", stks)
# Out:
# RangeIndex(start=0, stop=502, step=1)
# Industrials               ['MMM', 'AOS', 'ALLE', 'AME', 'ADP', 'AXON', 'BA', 'BR', 'BLDR', 'CHRW', 'CARR', 'CAT', 'CTAS', 'CPRT', 'CSX', 'CMI', 'DAY', 'DE', 'DAL', 'DOV', 'ETN', 'EMR', 'EFX', 'EXPD', 'FAST', 'FDX', 'FTV', 'GE', 'GEV', 'GNRC', 'GD', 'HON', 'HWM', 'HUBB', 'HII', 'IEX', 'ITW', 'IR', 'JBHT', 'J', 'JCI', 'LHX', 'LDOS', 'LMT', 'MAS', 'NDSN', 'NSC', 'NOC', 'ODFL', 'OTIS', 'PCAR', 'PH', 'PAYX', 'PAYC', 'PNR', 'PWR', 'RTX', 'RSG', 'ROK', 'ROL', 'SNA', 'LUV', 'SWK', 'TXT', 'TT', 'TDG', 'UBER', 'UNP', 'UAL', 'UPS', 'URI', 'VLTO', 'VRSK', 'GWW', 'WAB', 'WM', 'XYL']
# Financials                ['AFL', 'ALL', 'AXP', 'AIG', 'AMP', 'AON', 'ACGL', 'AJG', 'AIZ', 'BAC', 'BRK.B', 'BLK', 'BX', 'BK', 'BRO', 'COF', 'CBOE', 'SCHW', 'CB', 'CINF', 'C', 'CFG', 'CME', 'CPAY', 'DFS', 'ERIE', 'EG', 'FDS', 'FIS', 'FITB', 'FI', 'BEN', 'GPN', 'GL', 'GS', 'HIG', 'HBAN', 'ICE', 'IVZ', 'JKHY', 'JPM', 'KEY', 'KKR', 'L', 'MTB', 'MKTX', 'MMC', 'MA', 'MET', 'MCO', 'MS', 'MSCI', 'NDAQ', 'NTRS', 'PYPL', 'PNC', 'PFG', 'PGR', 'PRU', 'RJF', 'RF', 'SPGI', 'STT', 'SYF', 'TROW', 'TRV', 'TFC', 'USB', 'V', 'WRB', 'WFC', 'WTW']
# Information Technology    ['ACN', 'ADBE', 'AMD', 'AKAM', 'APH', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ANET', 'ADSK', 'AVGO', 'CDNS', 'CDW', 'CSCO', 'CTSH', 'GLW', 'CRWD', 'DELL', 'ENPH', 'EPAM', 'FFIV', 'FICO', 'FSLR', 'FTNT', 'IT', 'GEN', 'GDDY', 'HPE', 'HPQ', 'IBM', 'INTC', 'INTU', 'JBL', 'JNPR', 'KEYS', 'KLAC', 'LRCX', 'MCHP', 'MU', 'MSFT', 'MPWR', 'MSI', 'NTAP', 'NVDA', 'NXPI', 'ON', 'ORCL', 'PLTR', 'PANW', 'PTC', 'QRVO', 'QCOM', 'ROP', 'CRM', 'STX', 'NOW', 'SWKS', 'SMCI', 'SNPS', 'TEL', 'TDY', 'TER', 'TXN', 'TRMB', 'TYL', 'VRSN', 'WDC', 'ZBRA']
# Health Care               ['ABT', 'ABBV', 'A', 'ALGN', 'AMGN', 'BAX', 'BDX', 'TECH', 'BIIB', 'BSX', 'BMY', 'CAH', 'COR', 'CNC', 'CRL', 'CI', 'COO', 'CVS', 'DHR', 'DVA', 'DXCM', 'EW', 'ELV', 'GEHC', 'GILD', 'HCA', 'HSIC', 'HOLX', 'HUM', 'IDXX', 'INCY', 'PODD', 'ISRG', 'IQV', 'JNJ', 'LH', 'LLY', 'MCK', 'MDT', 'MRK', 'MTD', 'MRNA', 'MOH', 'PFE', 'DGX', 'REGN', 'RMD', 'RVTY', 'SOLV', 'STE', 'SYK', 'TFX', 'TMO', 'UNH', 'UHS', 'VRTX', 'VTRS', 'WAT', 'WST', 'ZBH', 'ZTS']
# Consumer Discretionary    ['ABNB', 'AMZN', 'APTV', 'AZO', 'BBY', 'BKNG', 'BWA', 'CZR', 'KMX', 'CCL', 'CMG', 'DRI', 'DECK', 'DPZ', 'DHI', 'EBAY', 'EXPE', 'F', 'GRMN', 'GM', 'GPC', 'HAS', 'HLT', 'HD', 'LVS', 'LEN', 'LKQ', 'LOW', 'LULU', 'MAR', 'MCD', 'MGM', 'MHK', 'NKE', 'NCLH', 'NVR', 'ORLY', 'POOL', 'PHM', 'RL', 'ROST', 'RCL', 'SBUX', 'TPR', 'TSLA', 'TJX', 'TSCO', 'ULTA', 'WYNN', 'YUM']
# Consumer Staples          ['MO', 'ADM', 'BF.B', 'BG', 'CPB', 'CHD', 'CLX', 'KO', 'CL', 'CAG', 'STZ', 'COST', 'DG', 'DLTR', 'EL', 'GIS', 'HSY', 'HRL', 'K', 'KVUE', 'KDP', 'KMB', 'KHC', 'KR', 'LW', 'MKC', 'TAP', 'MDLZ', 'MNST', 'PEP', 'PM', 'PG', 'SJM', 'SYY', 'TGT', 'TSN', 'WBA', 'WMT']
# Utilities                 ['AES', 'LNT', 'AEE', 'AEP', 'AWK', 'ATO', 'CNP', 'CMS', 'ED', 'CEG', 'D', 'DTE', 'DUK', 'EIX', 'ETR', 'EVRG', 'ES', 'EXC', 'FE', 'NEE', 'NI', 'NRG', 'PCG', 'PNW', 'PPL', 'PEG', 'SRE', 'SO', 'VST', 'WEC', 'XEL']
# Real Estate               ['ARE', 'AMT', 'AVB', 'BXP', 'CPT', 'CBRE', 'CSGP', 'CCI', 'DLR', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'DOC', 'HST', 'INVH', 'IRM', 'KIM', 'MAA', 'PLD', 'PSA', 'O', 'REG', 'SBAC', 'SPG', 'UDR', 'VTR', 'VICI', 'WELL', 'WY']
# Materials                 ['APD', 'ALB', 'AMCR', 'AVY', 'BALL', 'CE', 'CF', 'CTVA', 'DOW', 'DD', 'EMN', 'ECL', 'FMC', 'FCX', 'IFF', 'IP', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PKG', 'PPG', 'SHW', 'SW', 'STLD', 'VMC']
# Communication Services    ['GOOG', 'T', 'CHTR', 'CMCSA', 'EA', 'FOX', 'IPG', 'LYV', 'MTCH', 'META', 'NFLX', 'NWS', 'OMC', 'PARA', 'TMUS', 'TTWO', 'VZ', 'DIS', 'WBD']
# Energy                    ['APA', 'BKR', 'CVX', 'COP', 'CTRA', 'DVN', 'FANG', 'EOG', 'EQT', 'XOM', 'HAL', 'HES', 'KMI', 'MPC', 'OXY', 'OKE', 'PSX', 'SLB', 'TRGP', 'TPL', 'VLO', 'WMB']

# %%
series = pd.Series()
for sector in sectors:
    stks = by_industry[sector]
    series[sector] = (corr.loc[stks, stks].sum(0).sum(0) - len(stks)) / (len(stks) * (len(stks) - 1))

series.sort_values(inplace=True)

# %% [markdown]
# ## Inter-Sector

# %%
df_by_sector = pd.DataFrame()
for sector in sectors:
    stks = by_industry[sector]
    df_by_sector[sector] = (df[stks] * df_vol[stks]).sum(axis=1) / df_vol[stks].sum(axis=1)

df_sect_log = df_by_sector.iloc[:,:].apply(lambda x: np.log1p(x))
df_sector_diffs = df_sect_log - df_sect_log.shift()

display(df_sector_diffs.describe())

sector_corr = df_sector_diffs.corr()

sector_corr['sort_col'] = sector_corr.sum(axis=0)

sector_corr.sort_values(by='sort_col', inplace=True, ascending=False)

sector_corr.drop('sort_col', axis=1, inplace=True)

# permute columns to match sorted ordering
sector_corr = sector_corr[sector_corr.index]
# Out:
#        Industrials  Financials  Information Technology  Health Care  \
# count   141.000000  141.000000              141.000000   141.000000
# mean      0.000554    0.001443               -0.004078     0.000165
# std       0.059672    0.053193                0.078216     0.084975
# min      -0.190117   -0.179721               -0.516695    -0.192055
# 25%      -0.041655   -0.033384               -0.034222    -0.049521
# 50%       0.008547    0.004864               -0.001823     0.000381
# 75%       0.040380    0.028779                0.039592     0.047458
# max       0.145284    0.136357                0.210538     0.454286
#
#        Consumer Discretionary  Consumer Staples   Utilities  Real Estate  \
# count              141.000000        141.000000  141.000000   141.000000
# mean                 0.003173          0.000115   -0.000794     0.000885
# std                  0.103395          0.090084    0.064177     0.059375
# min                 -0.383580         -0.445076   -0.234151    -0.121366
# 25%                 -0.061109         -0.037454   -0.038023    -0.042682
# 50%                  0.009149         -0.001158    0.001992    -0.001121
# 75%                  0.062796          0.044370    0.038035     0.037285
# max                  0.306119          0.362707    0.181426     0.168128
#
#         Materials  Communication Services      Energy
# count  141.000000              141.000000  141.000000
# mean    -0.000908                0.002158   -0.000911
# std      0.091358                0.165914    0.063600
# min     -0.323616               -0.430701   -0.284552
# 25%     -0.047637               -0.098954   -0.039879
# 50%     -0.001874               -0.011372   -0.004687
# 75%      0.050855                0.110441    0.041001
# max      0.215409                0.467385    0.265193

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(series, orient='h')
plt.title('Correlation of Stocks within Industries')
plt.show()

sns.heatmap(sector_corr, vmax=0.2, vmin=-0.1, center=0, cmap='coolwarm')
plt.title('Correlation of Stocks between Industries')
plt.show()

# %% [markdown]
# ### Statistical Significance

# %%
from scipy.stats import t
import matplotlib.pyplot as plt

def p_value(n, dataframe: pd.DataFrame) -> pd.DataFrame:
    p_val = pd.DataFrame(index=dataframe.index, columns=dataframe.columns)
    for sector in sectors:
        t_stat = dataframe[sector] * np.sqrt((n - 2) / (1 - dataframe[sector]**2))
        p_val[sector] = 2 * t.sf(np.abs(t_stat), df=n-2)
        p_val.index = dataframe.index
    return p_val

pval = p_value(len(df_sector_diffs), sector_corr)
pval = pval[sector_corr.columns]
# shuffle indices to match sector_corr indices
pval = pval.loc[sector_corr.index]

# correlation heatmap
sns.heatmap(sector_corr, vmax=0.2, vmin=-0.1, center=0, cmap='coolwarm')
plt.title('Correlation of Stocks between Industries')
plt.show()

sns.heatmap(pval, vmax=0.1, vmin=0, center=0.05, cmap=plt.cm.coolwarm.reversed())
plt.title('P-Value of Correlation between Industries')
plt.show()

# %% [markdown]
# ### Strength of Correlation

# %%
def correlation_strength(corr: pd.DataFrame, pval: pd.DataFrame) -> pd.DataFrame:
    epsilon = 1e-20
    strength = pd.DataFrame(index=corr.index, columns=corr.columns)
    for sector in sectors:
        strength[sector] = corr[sector] * pval[sector].apply(lambda x: max(-np.log10(x + epsilon), 1))
        print(strength[sector])
    return strength

strength = correlation_strength(sector_corr, pval)
sns.heatmap(strength, vmax=0.5, vmin=-0.5, center=0, cmap='coolwarm')
plt.title('Strength of Correlation between Stocks between Industries')
plt.show()
# Out:
# Industrials               20.000000
# Financials                 1.890858
# Utilities                 -0.004843
# Information Technology     0.426576
# Energy                     0.398072
# Health Care                0.129361
# Consumer Staples          -0.047028
# Real Estate                0.176066
# Consumer Discretionary    -0.026691
# Materials                 -0.000024
# Communication Services    -0.093347
# Name: Industrials, dtype: float64
# Industrials                1.890858
# Financials                20.000000
# Utilities                  0.590120
# Information Technology     0.574128
# Energy                     0.111156
# Health Care                0.045237
# Consumer Staples          -0.256055
# Real Estate               -0.033250
# Consumer Discretionary     0.077371
# Materials                 -0.041925
# Communication Services    -0.107179
# Name: Financials, dtype: float64
# Industrials                0.426576
# Financials                 0.574128
# Utilities                  0.062543
# Information Technology    20.000000
# Energy                    -0.097187
# Health Care                0.062560
# Consumer Staples          -0.022557
# Real Estate               -0.037027
# Consumer Discretionary     0.062365
# Materials                 -0.031652
# Communication Services     0.013569
# Name: Information Technology, dtype: float64
# Industrials                0.129361
# Financials                 0.045237
# Utilities                 -0.045073
# Information Technology     0.062560
# Energy                    -0.256241
# Health Care               20.000000
# Consumer Staples           0.100300
# Real Estate                0.111722
# Consumer Discretionary     0.068230
# Materials                 -0.096681
# Communication Services     0.034099
# Name: Health Care, dtype: float64
# Industrials               -0.026691
# Financials                 0.077371
# Utilities                 -0.017503
# Information Technology     0.062365
# Energy                     0.040310
# Health Care                0.068230
# Consumer Staples           0.203395
# Real Estate               -0.069832
# Consumer Discretionary    20.000000
# Materials                 -0.070907
# Communication Services    -0.053543
# Name: Consumer Discretionary, dtype: float64
# Industrials               -0.047028
# Financials                -0.256055
# Utilities                 -0.059807
# Information Technology    -0.022557
# Energy                     0.037971
# Health Care                0.100300
# Consumer Staples          20.000000
# Real Estate               -0.028154
# Consumer Discretionary     0.203395
# Materials                  0.276281
# Communication Services     0.052243
# Name: Consumer Staples, dtype: float64
# Industrials               -0.004843
# Financials                 0.590120
# Utilities                 20.000000
# Information Technology     0.062543
# Energy                     0.185020
# Health Care               -0.045073
# Consumer Staples          -0.059807
# Real Estate                0.121257
# Consumer Discretionary    -0.017503
# Materials                  0.049426
# Communication Services     0.107775
# Name: Utilities, dtype: float64
# Industrials                0.176066
# Financials                -0.033250
# Utilities                  0.121257
# Information Technology    -0.037027
# Energy                     0.131151
# Health Care                0.111722
# Consumer Staples          -0.028154
# Real Estate               20.000000
# Consumer Discretionary    -0.069832
# Materials                 -0.034395
# Communication Services    -0.121213
# Name: Real Estate, dtype: float64
# Industrials               -0.000024
# Financials                -0.041925
# Utilities                  0.049426
# Information Technology    -0.031652
# Energy                     0.133018
# Health Care               -0.096681
# Consumer Staples           0.276281
# Real Estate               -0.034395
# Consumer Discretionary    -0.070907
# Materials                 20.000000
# Communication Services    -0.088722
# Name: Materials, dtype: float64
# Industrials               -0.093347
# Financials                -0.107179
# Utilities                  0.107775
# Information Technology     0.013569
# Energy                    -0.229244
# Health Care                0.034099
# Consumer Staples           0.052243
# Real Estate               -0.121213
# Consumer Discretionary    -0.053543
# Materials                 -0.088722
# Communication Services    20.000000
# Name: Communication Services, dtype: float64
# Industrials                0.398072
# Financials                 0.111156
# Utilities                  0.185020
# Information Technology    -0.097187
# Energy                    20.000000
# Health Care               -0.256241
# Consumer Staples           0.037971
# Real Estate                0.131151
# Consumer Discretionary     0.040310
# Materials                  0.133018
# Communication Services    -0.229244
# Name: Energy, dtype: float64

# %%
result = pd.concat([
    pd.Series(
        [df_sector_diffs[idx].corr(df_sector_diffs[col].shift()) for idx in df_sector_diffs.columns], 
        index=df_sector_diffs.columns) for col in df_sector_diffs.columns], axis=1)
result.columns = df_sector_diffs.columns

sns.heatmap(result, vmax=0.1, vmin=-0.1, center=0, cmap='coolwarm')
plt.title('Correlation of Stocks between Industries Shifted by 1 Day')
plt.show()

pval2 = p_value(len(df_sector_diffs) - 1, result)

pval2['sort_col'] = pval2.sum(axis=0)
pval2.sort_values(by='sort_col', inplace=True, ascending=False)
pval2.drop('sort_col', axis=1, inplace=True)
pval2 = pval2[pval2.index]

sns.heatmap(pval2, vmax=0.1, vmin=0, center=0.05,
            cmap=plt.cm.coolwarm.reversed())
plt.title('P-Values of Correlations of Stocks between Industries Shifted by 1 Day')
plt.show()

# %%
import cvxpy as cp
import numpy as np

# Problem data
Q = df_diff.cov().to_numpy()  
r = df_diff.mean(axis=0).to_numpy()        
betas = [.001, .0005, .0002, .0001]                     

for beta in betas:
    # Variables
    n = Q.shape[0]
    p = cp.Variable(n)
    print(n)
    print(r.shape)

    # Constraints
    constraints = [
        cp.sum(p) == 1,
        p @ r == beta,
        p >= 0
    ]

    # Objective
    objective = cp.Minimize(cp.quad_form(p, Q))

    # Solve
    problem = cp.Problem(objective, constraints)
    problem.solve()

    # Solution
    optimal_series = pd.Series(1000 * np.round(p.value, 3), index=df_diff.columns)
    optimal_series = optimal_series[optimal_series > 0]

    #print("Optimal p:", optimal_series)
    print(f"{beta:6} Optimal objective value:", problem.value)
# Out:
# 498
# (498,)
#  0.001 Optimal objective value: 7.099373581900512e-06
# 498
# (498,)
# 0.0005 Optimal objective value: 6.551338240983913e-06
# 498
# (498,)
# 0.0002 Optimal objective value: 6.620455559493271e-06
# 498
# (498,)
# 0.0001 Optimal objective value: 6.711734066149954e-06
